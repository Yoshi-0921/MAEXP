# %%
import torch

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


# Sentences we want sentence embeddings for
right_sentences = [
    "Explore the right area.",
    "Clean the right section.",
    "Inspect the right side of the environment.",
    "Move to the right zone and explore.",
    "Scan the right half of the room.",
    "Start cleaning the right area.",
    "Navigate to the right section and analyze.",
    "Focus on the right region.",
    "Proceed to explore the right side.",
    "Perform cleaning on the right area."
]
left_sentences = [
    "Explore the left region.",
    "Clean the left zone.",
    "Inspect the left side of the area.",
    "Move toward the left section and explore.",
    "Scan the left portion of the space.",
    "Begin cleaning operations on the left side.",
    "Navigate to the left area and perform analysis.",
    "Concentrate on the left half of the environment.",
    "Proceed to the left section for exploration.",
    "Execute cleaning tasks in the left region."
]

top_sentences = [
    "Explore the upper region of the environment.",
    "Clean the top area thoroughly.",
    "Inspect the upper section for any debris.",
    "Move to the top zone and begin exploration.",
    "Scan the upper part of the space.",
    "Start cleaning along the top side.",
    "Navigate toward the upper area for analysis.",
    "Focus your attention on the top half.",
    "Proceed to the upper section and explore.",
    "Perform cleaning operations in the top region."
]

bottom_sentences = [
    "Explore the lower region of the environment.",
    "Clean the bottom area completely.",
    "Inspect the lower section for dirt or obstacles.",
    "Move to the bottom zone and begin exploration.",
    "Scan the lower part of the space carefully.",
    "Start cleaning operations on the bottom side.",
    "Navigate toward the lower area for inspection.",
    "Focus on exploring the bottom half of the environment.",
    "Proceed to the lower section and analyze the area.",
    "Perform cleaning tasks in the bottom region."
]

entire_sentences = [
    "Explore the entire area.",
    "Clean the whole environment thoroughly.",
    "Inspect the full area for any debris or obstacles.",
    "Move across the entire space and explore.",
    "Scan the whole environment carefully.",
    "Start cleaning operations throughout the entire area.",
    "Navigate across the full region for inspection.",
    "Focus on covering the entire space.",
    "Proceed to explore the complete environment.",
    "Perform cleaning tasks across the whole area."
]

top_right_sentences = [
    "Begin by examining the area located in the upper-right portion of the map.",
    "Shift your attention to the top-right region and explore it.",
    "Investigate what lies in the upper-right section of the environment.",
    "Carry out an exploration task in the region situated at the top right.",
    "Please prioritize checking the upper-right area.",
    "Move diagonally upward to the right and survey the surroundings.",
    "Inspect the top-right quadrant for any relevant features.",
    "Explore the area that lies above and to the right of your current position.",
    "Focus on the environment segment located in the upper-right corner.",
    "Proceed toward the top-right side and assess the region."
]

top_left_sentences = [
    "Explore the region positioned along the upper-left boundary.",
    "Direct your movement toward the top-left side of the environment.",
    "Examine the area extending upward and to the left.",
    "Survey the upper-left zone and identify its characteristics.",
    "Please investigate the section located at the top-left corner.",
    "Navigate toward the left while moving upward to explore that area.",
    "Inspect the top-left quadrant of the map.",
    "Focus your exploration on the region above and to the left.",
    "Assess the environment’s upper-left section carefully.",
    "Search the area located in the top-left portion of the map."

]

bottom_right_sentences = [
    "Move downward and to the right to explore the lower-right region.",
    "Survey the environment area located in the bottom-right section.",
    "Inspect the region extending below and to the right.",
    "Please examine the lower-right corner of the environment.",
    "Navigate toward the bottom-right side and investigate the area.",
    "Conduct a detailed search of the bottom-right quadrant.",
    "Focus on exploring the region situated beneath and to the right.",
    "Assess the lower-right zone for relevant information.",
    "Proceed to the bottom-right portion of the map and explore it.",
    "Explore the environment area located at the lower-right boundary."

]

bottom_left_sentences = [
    "Direct your exploration toward the lower-left portion of the environment.",
    "Move down and to the left to examine that region.",
    "Inspect the area situated at the bottom-left corner.",
    "Survey the environment region located beneath and to the left.",
    "Please investigate the lower-left section of the map.",
    "Navigate toward the bottom-left side and assess the surroundings.",
    "Conduct an exploration of the bottom-left quadrant.",
    "Focus on the region extending downward and to the left.",
    "Explore the area located along the lower-left boundary.",
    "Examine the environment’s bottom-left zone carefully."
]

new_right_sentences = ["Explore right region of the environment.","Go to right region.","Clean the right area of the room."]
new_left_sentences = ["Explore left region of the environment.","Go to left region.","Clean the left area of the room."]
new_top_sentences = ["Explore top region of the environment.","Go to top region.","Clean the top area of the room."]
new_bottom_sentences = ["Explore bottom region of the environment.","Go to bottom region.","Clean the bottom area of the room."]

new_top_right_sentences = ["Explore both top and right region of the environment.","Go to top and right of the region.","Clean the top and right area of the room."]
new_top_left_sentences = ["Explore both top and left region of the environment.","Go to top and left of the region.","Clean the top and left area of the room."]
new_bottom_right_sentences = ["Explore both bottom and right region of the environment.","Go to bottom and right of the region.","Clean the bottom and right area of the room."]
new_bottom_left_sentences = ["Explore both bottom and left region of the environment.","Go to bottom and left of the region.","Clean the bottom and left area of the room."]

new_top_bottom_sentences = ["Explore both top and bottom region of the environment.","Go to top and bottom of the region.","Clean the top and bottom area of the room."]
new_right_left_sentences = ["Explore both right and left region of the environment.","Go to right and left of the region.","Clean the right and left area of the room."]
# Out:
# The kernel failed to start as '/home/motokawa/miniconda3/envs/textStrat/lib/python3.9/site-packages/psutil/_psutil_linux.cpython-39-x86_64-linux-gnu.so' could not be imported from '5.8.0 instead of 7.0.0'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
from transformers import AutoTokenizer, AutoModel
import torch.nn.functional as F

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# Tokenize sentences
encoded_input = tokenizer(top_right_sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Perform pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

print("Sentence embeddings:")
print(sentence_embeddings)

torch.save(sentence_embeddings,"top_right_tensor")

# %%
from transformers import AutoTokenizer, AutoModel
import torch.nn.functional as F

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# Tokenize sentences
encoded_input = tokenizer(["Explore both top and bottom region of the environment.","Go to top and bottom of the region.","Clean the top and bottom area of the room."], padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Perform pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

print("Sentence embeddings:")
print(sentence_embeddings)

torch.save(sentence_embeddings,"new_top_bottom_tensor")
