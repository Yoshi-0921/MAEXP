# %%
import torch

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


# Sentences we want sentence embeddings for
all_all_sentences = [
    "Collect all objects throughout the environment.",
    "Gather items of every type across the entire area.",
    "Retrieve all available objects without restriction.",
    "Explore freely and pick up all objects you encounter.",
    "Focus on collecting every object in the environment.",
    "Search the entire space and gather all items.",
    "Do not restrict your collection—acquire all objects.",
    "Move across the environment and collect everything.",
    "Ensure all objects are collected from all regions.",
    "Collect objects regardless of type or location."
]

all_left_sentences = [
    "Collect all objects located in the left region.",
    "Gather every item on the left side of the environment.",
    "Focus on retrieving objects from the left area.",
    "Search the left region and pick up all objects.",
    "Collect everything you find on the left side.",
    "Restrict your collection to the left region only.",
    "Explore the left area and gather all items.",
    "Acquire all objects situated in the left portion.",
    "Ensure all objects on the left are collected.",
    "Move to the left side and collect every object there."
]

all_right_sentences = [
    "Collect all objects located in the right region.",
    "Gather every item on the right side of the environment.",
    "Focus on retrieving objects from the right area.",
    "Search the right region and pick up all objects.",
    "Collect everything you find on the right side.",
    "Restrict your collection to the right region only.",
    "Explore the right area and gather all items.",
    "Acquire all objects situated in the right portion.",
    "Ensure all objects on the right are collected.",
    "Move to the right side and collect every object there."
]

all_top_sentences = [
    "Collect all objects located in the top region.",
    "Gather every item in the upper area of the environment.",
    "Focus on retrieving objects from the top side.",
    "Search the upper region and pick up all objects.",
    "Collect everything you find in the top area.",
    "Restrict your collection to the upper region only.",
    "Explore the top area and gather all items.",
    "Acquire all objects situated in the upper portion.",
    "Ensure all objects in the top region are collected.",
    "Move to the upper side and collect every object there."
]

all_bottom_sentences = [
    "Collect all objects located in the bottom region.",
    "Gather every item in the lower area of the environment.",
    "Focus on retrieving objects from the bottom side.",
    "Search the lower region and pick up all objects.",
    "Collect everything you find in the bottom area.",
    "Restrict your collection to the lower region only.",
    "Explore the bottom area and gather all items.",
    "Acquire all objects situated in the lower portion.",
    "Ensure all objects in the bottom region are collected.",
    "Move to the lower side and collect every object there."
]

type0_all_sentences = [
    "Collect all type 0 objects in the environment.",
    "Gather every item classified as type 0.",
    "Focus on retrieving objects of type 0 only.",
    "Search the entire area for type 0 items.",
    "Collect all available type 0 objects.",
    "Explore the environment and gather type 0 items.",
    "Acquire all objects belonging to type 0.",
    "Ensure only type 0 objects are collected.",
    "Move around and pick up type 0 items.",
    "Collect type 0 objects regardless of location."
]

type0_left_sentences = [
    "Collect type 0 objects in the left region.",
    "Gather type 0 items located on the left side.",
    "Focus on retrieving type 0 objects from the left area.",
    "Search the left region for type 0 items.",
    "Collect only type 0 objects on the left side.",
    "Explore the left area and gather type 0 items.",
    "Acquire type 0 objects situated in the left portion.",
    "Ensure type 0 objects on the left are collected.",
    "Move to the left region and collect type 0 items.",
    "Restrict your collection to type 0 objects in the left area."
]

type0_right_sentences = [
    "Collect type 0 objects in the right region.",
    "Gather type 0 items located on the right side.",
    "Focus on retrieving type 0 objects from the right area.",
    "Search the right region for type 0 items.",
    "Collect only type 0 objects on the right side.",
    "Explore the right area and gather type 0 items.",
    "Acquire type 0 objects situated in the right portion.",
    "Ensure type 0 objects on the right are collected.",
    "Move to the right region and collect type 0 items.",
    "Restrict your collection to type 0 objects in the right area."
]

type0_top_sentences = [
    "Collect type 0 objects in the top region.",
    "Gather type 0 items in the upper area.",
    "Focus on retrieving type 0 objects from the top side.",
    "Search the upper region for type 0 items.",
    "Collect only type 0 objects in the top area.",
    "Explore the upper area and gather type 0 items.",
    "Acquire type 0 objects located in the top portion.",
    "Ensure type 0 objects in the top region are collected.",
    "Move to the top side and collect type 0 items.",
    "Restrict your collection to type 0 objects in the upper area."
]

type0_bottom_sentences = [
    "Collect type 0 objects in the bottom region.",
    "Gather type 0 items in the lower area.",
    "Focus on retrieving type 0 objects from the bottom side.",
    "Search the lower region for type 0 items.",
    "Collect only type 0 objects in the bottom area.",
    "Explore the lower area and gather type 0 items.",
    "Acquire type 0 objects located in the bottom portion.",
    "Ensure type 0 objects in the bottom region are collected.",
    "Move to the bottom side and collect type 0 items.",
    "Restrict your collection to type 0 objects in the lower area."
]

type1_all_sentences = [
    "Collect all type 1 objects in the environment.",
    "Gather every item classified as type 1.",
    "Focus on retrieving objects of type 1 only.",
    "Search the entire area for type 1 items.",
    "Collect all available type 1 objects.",
    "Explore the environment and gather type 1 items.",
    "Acquire all objects belonging to type 1.",
    "Ensure only type 1 objects are collected.",
    "Move around and pick up type 1 items.",
    "Collect type 1 objects regardless of location."
]

type1_left_sentences = [
    "Collect type 1 objects in the left region.",
    "Gather type 1 items located on the left side.",
    "Focus on retrieving type 1 objects from the left area.",
    "Search the left region for type 1 items.",
    "Collect only type 1 objects on the left side.",
    "Explore the left area and gather type 1 items.",
    "Acquire type 1 objects situated in the left portion.",
    "Ensure type 1 objects on the left are collected.",
    "Move to the left region and collect type 1 items.",
    "Restrict your collection to type 1 objects in the left area."
]

type1_right_sentences = [
    "Collect type 1 objects in the right region.",
    "Gather type 1 items located on the right side.",
    "Focus on retrieving type 1 objects from the right area.",
    "Search the right region for type 1 items.",
    "Collect only type 1 objects on the right side.",
    "Explore the right area and gather type 1 items.",
    "Acquire type 1 objects situated in the right portion.",
    "Ensure type 1 objects on the right are collected.",
    "Move to the right region and collect type 1 items.",
    "Restrict your collection to type 1 objects in the right area."
]

type1_top_sentences = [
    "Collect type 1 objects in the top region.",
    "Gather type 1 items in the upper area.",
    "Focus on retrieving type 1 objects from the top side.",
    "Search the upper region for type 1 items.",
    "Collect only type 1 objects in the top area.",
    "Explore the upper area and gather type 1 items.",
    "Acquire type 1 objects located in the top portion.",
    "Ensure type 1 objects in the top region are collected.",
    "Move to the top side and collect type 1 items.",
    "Restrict your collection to type 1 objects in the upper area."
]

type1_bottom_sentences = [
    "Collect type 1 objects in the bottom region.",
    "Gather type 1 items in the lower area.",
    "Focus on retrieving type 1 objects from the bottom side.",
    "Search the lower region for type 1 items.",
    "Collect only type 1 objects in the bottom area.",
    "Explore the lower area and gather type 1 items.",
    "Acquire type 1 objects located in the bottom portion.",
    "Ensure type 1 objects in the bottom region are collected.",
    "Move to the bottom side and collect type 1 items.",
    "Restrict your collection to type 1 objects in the lower area."
]

# %%
unseen_type0_left_sentences = [
    "Retrieve type 0 targets positioned in the left sector.",
    "Head toward the left side and secure type 0 objects.",
    "Prioritize collecting type 0 items from the left portion.",
    "Locate and obtain type 0 targets within the left zone.",
    "Limit retrieval to type 0 objects appearing on the left."
]

unseen_type0_right_sentences = [
    "Retrieve type 0 targets positioned in the right sector.",
    "Head toward the right side and secure type 0 objects.",
    "Prioritize collecting type 0 items from the right portion.",
    "Locate and obtain type 0 targets within the right zone.",
    "Limit retrieval to type 0 objects appearing on the right."
]

unseen_type0_top_sentences = [
    "Retrieve type 0 targets positioned in the upper sector.",
    "Head toward the top side and secure type 0 objects.",
    "Prioritize collecting type 0 items from the upper portion.",
    "Locate and obtain type 0 targets within the top zone.",
    "Limit retrieval to type 0 objects appearing in the upper area."
]

unseen_type0_bottom_sentences = [
    "Retrieve type 0 targets positioned in the lower sector.",
    "Head toward the bottom side and secure type 0 objects.",
    "Prioritize collecting type 0 items from the lower portion.",
    "Locate and obtain type 0 targets within the bottom zone.",
    "Limit retrieval to type 0 objects appearing in the lower area."
]

unseen_type1_left_sentences = [
    "Retrieve type 1 targets positioned in the left sector.",
    "Head toward the left side and secure type 1 objects.",
    "Prioritize collecting type 1 items from the left portion.",
    "Locate and obtain type 1 targets within the left zone.",
    "Limit retrieval to type 1 objects appearing on the left."
]

unseen_type1_right_sentences = [
    "Retrieve type 1 targets positioned in the right sector.",
    "Head toward the right side and secure type 1 objects.",
    "Prioritize collecting type 1 items from the right portion.",
    "Locate and obtain type 1 targets within the right zone.",
    "Limit retrieval to type 1 objects appearing on the right."
]

unseen_type1_top_sentences = [
    "Retrieve type 1 targets positioned in the upper sector.",
    "Head toward the top side and secure type 1 objects.",
    "Prioritize collecting type 1 items from the upper portion.",
    "Locate and obtain type 1 targets within the top zone.",
    "Limit retrieval to type 1 objects appearing in the upper area."
]

unseen_type1_bottom_sentences = [
    "Retrieve type 1 targets positioned in the lower sector.",
    "Head toward the bottom side and secure type 1 objects.",
    "Prioritize collecting type 1 items from the lower portion.",
    "Locate and obtain type 1 targets within the bottom zone.",
    "Limit retrieval to type 1 objects appearing in the lower area."
]

# %%
from transformers import AutoTokenizer, AutoModel
import torch.nn.functional as F

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# Tokenize sentences
encoded_input = tokenizer(type1_all_sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Perform pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

print("Sentence embeddings:")
print(sentence_embeddings)

torch.save(sentence_embeddings,"type1_all_tensor")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /home/motokawa/miniconda3/envs/textStrat/lib/python3.9/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Sentence embeddings:
# tensor([[ 0.0592,  0.0427,  0.0021,  ..., -0.0116, -0.0242,  0.0372],
#         [ 0.0104,  0.0323,  0.0248,  ..., -0.0058,  0.0120,  0.0580],
#         [ 0.0130,  0.0408,  0.0049,  ...,  0.0027,  0.0128,  0.0767],
#         ...,
#         [ 0.0296,  0.0536, -0.0235,  ..., -0.0192, -0.0052,  0.0126],
#         [ 0.0162, -0.0509,  0.0516,  ..., -0.0560, -0.0719,  0.0378],
# ...

# %%
from transformers import AutoTokenizer, AutoModel
import torch.nn.functional as F

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# Tokenize sentences
encoded_input = tokenizer(unseen_type0_bottom_sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Perform pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

print("Sentence embeddings:")
print(sentence_embeddings)

torch.save(sentence_embeddings,"unseen_type0_bottom_tensor")
# Out:
# Sentence embeddings:
# tensor([[ 0.0973,  0.0352, -0.0631,  ...,  0.0127, -0.0152,  0.1023],
#         [ 0.0098,  0.0564, -0.0920,  ...,  0.0887,  0.0216, -0.0104],
#         [ 0.0236,  0.1018,  0.0133,  ..., -0.0558, -0.0934,  0.0766],
#         [ 0.0989,  0.0283, -0.0311,  ...,  0.0121, -0.0576,  0.0272],
#         [ 0.0276,  0.0704, -0.0057,  ...,  0.0509, -0.0634,  0.0861]])
